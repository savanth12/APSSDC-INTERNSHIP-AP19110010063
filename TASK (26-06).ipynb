# %% [markdown]
# ## TASK - 1:
# * Take one dataset and plot all graphs.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
d = pd.read_csv("https://raw.githubusercontent.com/LavanyaPolamarasetty/Datasets/master/Classification/Social_Network_Ads.csv")
d
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
d.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %% [markdown]
# ### Line plot:

# %%
plt.plot(d["Age"])
plt.title("Line Plot")
plt.xlabel("Age")
plt.show()

# %% [markdown]
# ### Bar graph:

# %%
plt.bar(d["Gender"],d["EstimatedSalary"])
plt.title("Bar Graph")
plt.xlabel("Gender")
plt.ylabel("Estimated salary")
plt.show()

# %% [markdown]
# ### Scatter Plot:

# %%
plt.scatter(d["Age"],d["EstimatedSalary"])
plt.title("Scatter Plot")
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.show()

# %% [markdown]
# ### Histogram:

# %%
plt.hist(d["Age"])
plt.title("Histogram")
plt.xlabel("Age")
plt.ylabel("Frequency count of age")
# Out:
# Text(0, 0.5, 'Frequency count of age')

# %% [markdown]
# ### Pie Chart:

# %%
plt.pie(d["EstimatedSalary"][:10],labels = d["Age"][:10], autopct = "% 1f%%")
plt.show()

# %% [markdown]
# ### Box Plot:

# %%
plt.boxplot(d["EstimatedSalary"])
plt.title("Box Plot")
plt.xlabel("Estimated Salary")
plt.show()

# %% [markdown]
# ### Subplot:

# %%
fig, area = plt.subplots(2, 2)
area[0][0].plot(d['Age'])
area[0][1].plot(d['Gender'])
area[1][0].plot(d['EstimatedSalary'])
area[1][1].plot(d['Purchased'])
plt.show()

# %%
plt.subplot(1, 2, 2)
plt.plot(d['EstimatedSalary'])
plt.subplot(1, 2, 1)
plt.plot(d['Gender'])
plt.show()
